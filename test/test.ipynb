# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.imagenet_utils import preprocess_input

# Load the pre-trained model
model = load_model('./model_blood_group_detection_resnet.h5')

# Define the class labels
labels = {'A+': 0, 'A-': 1, 'AB+': 2, 'AB-': 3, 'B+': 4, 'B-': 5, 'O+': 6, 'O-': 7}
labels = dict((v, k) for k, v in labels.items())

# Example of loading a single image and making a prediction
img_path = "O- blood group.BMP"

img = image.load_img(img_path, target_size=(256, 256))  # Load the image|
x = image.img_to_array(img)  # Convert image to array
x = np.expand_dims(x, axis=0)  # Expand dimensions to match the model input
x = preprocess_input(x)  # Preprocess the image

result = model.predict(x)  # Predict using the model
predicted_class = np.argmax(result)  # Get the predicted class index

# Map the predicted class to the label
predicted_label = labels[predicted_class]
confidence = result[0][predicted_class] * 100  # Confidence level

# Display the image
plt.imshow(image.array_to_img(image.img_to_array(img) / 255.0))
plt.axis('off')  # Hide axes

# Display the prediction and confidence below the image
plt.title(f"Prediction: {predicted_label} with confidence {confidence:.2f}%")
plt.show()
# Out:
# -------------------------------------------------------------------------
# ValueError                              Traceback (most recent call last)
# Cell In[3], line 8
#       5 from tensorflow.keras.applications.imagenet_utils import preprocess_input
#       7 # Load the pre-trained model
# ----> 8 model = load_model('./model_blood_group_detection_resnet.h5')
#      10 # Define the class labels
#      11 labels = {'A+': 0, 'A-': 1, 'AB+': 2, 'AB-': 3, 'B+': 4, 'B-': 5, 'O+': 6, 'O-': 7}
#
# File C:\My D Drive\finger_print_detection\fingerprint-based-blood-group-detection\.venv\lib\site-packages\tensorflow\python\keras\saving\save.py:206, in load_model(filepath, custom_objects, compile, options)
#     203 with load_context.load_context(options):
#     204   if (h5py is not None and
#     205       (isinstance(filepath, h5py.File) or h5py.is_hdf5(filepath))):
# --> 206     return hdf5_format.load_model_from_hdf5(filepath, custom_objects,
#     207                                             compile)
#     209   filepath = path_to_string(filepath)
#     210   if isinstance(filepath, six.string_types):
#
# File C:\My D Drive\finger_print_detection\fingerprint-based-blood-group-detection\.venv\lib\site-packages\tensorflow\python\keras\saving\hdf5_format.py:183, in load_model_from_hdf5(filepath, custom_objects, compile)
#     181   raise ValueError('No model found in config file.')
#     182 model_config = json_utils.decode(model_config.decode('utf-8'))
# --> 183 model = model_config_lib.model_from_config(model_config,
#     184                                            custom_objects=custom_objects)
#     186 # set weights
#     187 load_weights_from_hdf5_group(f['model_weights'], model.layers)
#
# File C:\My D Drive\finger_print_detection\fingerprint-based-blood-group-detection\.venv\lib\site-packages\tensorflow\python\keras\saving\model_config.py:64, in model_from_config(config, custom_objects)
#      60   raise TypeError('`model_from_config` expects a dictionary, not a list. '
#      61                   'Maybe you meant to use '
#      62                   '`Sequential.from_config(config)`?')
#      63 from tensorflow.python.keras.layers import deserialize  # pylint: disable=g-import-not-at-top
# ---> 64 return deserialize(config, custom_objects=custom_objects)
#
# File C:\My D Drive\finger_print_detection\fingerprint-based-blood-group-detection\.venv\lib\site-packages\tensorflow\python\keras\layers\serialization.py:173, in deserialize(config, custom_objects)
#     162 """Instantiates a layer from a config dictionary.
#     163
#     164 Arguments:
#    (...)
#     170     Layer instance (may be Model, Sequential, Network, Layer...)
#     171 """
#     172 populate_deserializable_objects()
# --> 173 return generic_utils.deserialize_keras_object(
#     174     config,
#     175     module_objects=LOCAL.ALL_OBJECTS,
#     176     custom_objects=custom_objects,
#     177     printable_module_name='layer')
#
# File C:\My D Drive\finger_print_detection\fingerprint-based-blood-group-detection\.venv\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py:354, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     351 custom_objects = custom_objects or {}
#     353 if 'custom_objects' in arg_spec.args:
# --> 354   return cls.from_config(
#     355       cls_config,
#     356       custom_objects=dict(
#     357           list(_GLOBAL_CUSTOM_OBJECTS.items()) +
#     358           list(custom_objects.items())))
#     359 with CustomObjectScope(custom_objects):
#     360   return cls.from_config(cls_config)
#
# File C:\My D Drive\finger_print_detection\fingerprint-based-blood-group-detection\.venv\lib\site-packages\tensorflow\python\keras\engine\functional.py:668, in Functional.from_config(cls, config, custom_objects)
#     652 @classmethod
#     653 def from_config(cls, config, custom_objects=None):
#     654   """Instantiates a Model from its config (output of `get_config()`).
#     655
#     656   Arguments:
#    (...)
#     666       ValueError: In case of improperly formatted config dict.
#     667   """
# --> 668   input_tensors, output_tensors, created_layers = reconstruct_from_config(
#     669       config, custom_objects)
#     670   model = cls(inputs=input_tensors, outputs=output_tensors,
#     671               name=config.get('name'))
#     672   connect_ancillary_layers(model, created_layers)
#
# File C:\My D Drive\finger_print_detection\fingerprint-based-blood-group-detection\.venv\lib\site-packages\tensorflow\python\keras\engine\functional.py:1275, in reconstruct_from_config(config, custom_objects, created_layers)
#    1273 # First, we create all layers and enqueue nodes to be processed
#    1274 for layer_data in config['layers']:
# -> 1275   process_layer(layer_data)
#    1276 # Then we process nodes in order of layer depth.
#    1277 # Nodes that cannot yet be processed (if the inbound node
#    1278 # does not yet exist) are re-enqueued, and the process
#    1279 # is repeated until all nodes are processed.
#    1280 while unprocessed_nodes:
#
# File C:\My D Drive\finger_print_detection\fingerprint-based-blood-group-detection\.venv\lib\site-packages\tensorflow\python\keras\engine\functional.py:1257, in reconstruct_from_config.<locals>.process_layer(layer_data)
#    1253 else:
#    1254   # Instantiate layer.
#    1255   from tensorflow.python.keras.layers import deserialize as deserialize_layer  # pylint: disable=g-import-not-at-top
# -> 1257   layer = deserialize_layer(layer_data, custom_objects=custom_objects)
#    1258   created_layers[layer_name] = layer
#    1260 node_count_by_layer[layer] = int(_should_skip_first_node(layer))
#
# File C:\My D Drive\finger_print_detection\fingerprint-based-blood-group-detection\.venv\lib\site-packages\tensorflow\python\keras\layers\serialization.py:173, in deserialize(config, custom_objects)
#     162 """Instantiates a layer from a config dictionary.
#     163
#     164 Arguments:
#    (...)
#     170     Layer instance (may be Model, Sequential, Network, Layer...)
#     171 """
#     172 populate_deserializable_objects()
# --> 173 return generic_utils.deserialize_keras_object(
#     174     config,
#     175     module_objects=LOCAL.ALL_OBJECTS,
#     176     custom_objects=custom_objects,
#     177     printable_module_name='layer')
#
# File C:\My D Drive\finger_print_detection\fingerprint-based-blood-group-detection\.venv\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py:360, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     354     return cls.from_config(
#     355         cls_config,
#     356         custom_objects=dict(
#     357             list(_GLOBAL_CUSTOM_OBJECTS.items()) +
#     358             list(custom_objects.items())))
#     359   with CustomObjectScope(custom_objects):
# --> 360     return cls.from_config(cls_config)
#     361 else:
#     362   # Then `cls` may be a function returning a class.
#     363   # in this case by convention `config` holds
#     364   # the kwargs of the function.
#     365   custom_objects = custom_objects or {}
#
# File C:\My D Drive\finger_print_detection\fingerprint-based-blood-group-detection\.venv\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:720, in Layer.from_config(cls, config)
#     704 @classmethod
#     705 def from_config(cls, config):
#     706   """Creates a layer from its config.
#     707
#     708   This method is the reverse of `get_config`,
#    (...)
#     718       A layer instance.
#     719   """
# --> 720   return cls(**config)
#
# File C:\My D Drive\finger_print_detection\fingerprint-based-blood-group-detection\.venv\lib\site-packages\tensorflow\python\keras\engine\input_layer.py:118, in InputLayer.__init__(self, input_shape, batch_size, dtype, input_tensor, sparse, name, ragged, **kwargs)
#     116   input_shape = batch_input_shape[1:]
#     117 if kwargs:
# --> 118   raise ValueError('Unrecognized keyword arguments:', kwargs.keys())
#     120 if sparse and ragged:
#     121   raise ValueError(
#     122       'Cannot set both sparse and ragged to True in a Keras input.')
#
# ValueError: ('Unrecognized keyword arguments:', dict_keys(['batch_shape']))
